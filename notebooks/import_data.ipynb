# %%
from biokb_taxtree.db.manager import DbManager
from sqlalchemy import create_engine

# %% [markdown]
# # Demo Insert data

# %% [markdown]
# This notebook demonstrates how data from NCBI can be imported into the database.

# %% [markdown]
# ## SQLite
#
# Please note that in the same folder a SQLite file ***test.db*** is create which can also be open with application like [DBBrowser for SQLite](https://sqlitebrowser.org/). **DBBrowser for SQLite** can be installed on Ubuntu with with `sudo apt install sqlitebrowser`. Other option to install on Windows, MacOS or Linux this check please [here](https://sqlitebrowser.org/dl/)

# %%
engine = create_engine("sqlite:///test.db")
dbm = DbManager(engine)
dbm.import_data()
# Out:
# INFO:biokb_taxtree.db.manager:Start import data with engine Engine(sqlite:///test.db)
# INFO:biokb_taxtree.db.manager:Start import nodes
# INFO:biokb_taxtree.db.manager:Start import ranked lineage
# INFO:biokb_taxtree.db.manager:Start import names
# INFO:biokb_taxtree.db.manager:Data imported.

# %% [markdown]
# ## MySQL

# %% [markdown]
# Alternatively, the data can also be imported into MySQL. To do this, please execute the following command, remove the comment characters (#) in the next cell and execute the cell.
#
# ```bash
# podman-compose up -d mysql
# ```

# %%
# engine = create_engine("mysql+pymysql://db_user:db_passwd@localhost:3307/taxtree")
# dbm = DbManager(engine)
# dbm.import_data()
