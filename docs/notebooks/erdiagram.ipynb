# %%
from eralchemy import render_er
from biokb_taxtree.db.models import Base
import os
from eralchemy import render_er
from eralchemy.cst import dot_crowfoot, dot_digraph

dot_crowfoot()
dot_digraph()

# %% [markdown]
# # Entity-relationship diagram

# %% [markdown]
# This notebook is used to generate an entity-relationship diagram from the SQLAlchemy models defined in the `biokb_taxtree` package.

# %%
render_er(Base, os.path.join("..", "imgs", "erd_from_sqlalchemy.png"))

# %% [markdown]
# ![ER model](https://raw.githubusercontent.com/biokb/biokb_taxtree/refs/heads/main/docs/imgs/erd_from_sqlalchemy.png)

# %% [markdown]
# ![](../assets/biokb_logo.png)
