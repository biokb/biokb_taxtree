# %%
from biokb_taxtree.db.manager import DbManager
from biokb_taxtree.rdf.turtle import TurtleCreator
from biokb_taxtree.rdf.neo4j_importer import Neo4jImporter
import os.path

# %% [markdown]
# # Test the workflow with default settings
#
# On 11th Gen Intel(R) Core(TM) i7-1195G7 @ 2.90GHz: ~5min starting from empty sqlite.

# %% [markdown]
# Before starting the import into neo4j start a test container with:
# ```bash
# podman run --rm --name biokb-neo4j-test -p7474:7474 -p7687:7687 -e NEO4J_AUTH=neo4j/neo4j_password neo4j:latest
# ```

# %%
os.environ.pop("CONNECTION_STR", None)  # to make sure default is used
DbManager().import_data()
# starting from taxid 3193: Embryophyta  (land plants) and taxid 40674: Mammalia  (mammals)
TurtleCreator().create_ttls([3193, 40674])

# %%
Neo4jImporter().import_ttls()

# %% [markdown]
# Open Neo4j [browser](http://localhost:7474), login with neo4j/neo4j_password
