# %%
from sqlalchemy import create_engine
from biokb_taxtree.rdf.turtle import TurtleCreator
from biokb_taxtree.db import models

# %%
embryophyta_tax_id = 3193
mammalia_tax_id = 40674

# %%
engine = create_engine("mysql+pymysql://biokb_user:biokb_passwd@localhost/biokb")
tc = TurtleCreator(engine)

# %%
tc.create_ttls([embryophyta_tax_id, mammalia_tax_id])
# tc.create_ttls([9606])
# Out:
# '/home/ceb/.biokb/taxtree/data/ttls.zip'
