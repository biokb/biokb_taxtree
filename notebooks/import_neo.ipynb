# %%
from biokb_taxtree.rdf.neo4j_importer import Neo4jImporter

# %%
ni = Neo4jImporter()
ni.import_ttls()
# Out:
# Uniqueness constraint on :Resource(uri) found.
#
#
# The store is now: Open
# Processing taxtree_node_3193.ttl: 100%|██████████| 2/2 [00:48<00:00, 24.41s/it]
# The store is now: Closed
# IMPORTED 1377175 TRIPLES
# True
